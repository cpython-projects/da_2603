# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/da_2603/blob/main/lesson_28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Что такое API
#
# ## API (Application Programming Interface)
#
# * Это «программа для общения с программой».
# * Через API можно получать данные от внешних сервисов.
# * Часто используется формат **JSON**.
#
# ## Типы API
#
# * **Публичные** (без авторизации): можно сразу делать запрос.
# * **С авторизацией**: нужен ключ (`api_key` или `token`) — как пароль.
#
# ## Где искать API
#
# * На сайтах сервисов → раздел *Developers* или *API Docs*
# * Примеры:
#
#   * [CoinGecko API (без ключа)](https://www.coingecko.com/en/api/documentation)
#   * [CoinMarketCap API (нужен ключ)](https://coinmarketcap.com/api/)
#   * [OpenWeatherMap](https://openweathermap.org/api)
#   * [NASA API](https://api.nasa.gov/)

# %% [markdown]
# # Работа с публичным API (CoinGecko)

# %% [markdown]
# **Найдём нужный endpoint**
#
# * Документация CoinGecko: [https://www.coingecko.com/en/api/documentation](https://www.coingecko.com/en/api/documentation)
# * Выбираем: `/coins/markets`
#
# ```http
# GET https://api.coingecko.com/api/v3/coins/markets
# ?vs_currency=usd&order=market_cap_desc&per_page=10&page=1
# ```

# %% [markdown]
# **Отправим запрос через Python**

# %%
import requests

url = "https://api.coingecko.com/api/v3/coins/markets"
params = {
    "vs_currency": "usd",
    "order": "market_cap_desc",
    "per_page": 10,
    "page": 1
}

response = requests.get(url, params=params)
print(response.status_code)
data = response.json()
# Out:
# 200

# %%
print(data)
# Out:
# [{'id': 'bitcoin', 'symbol': 'btc', 'name': 'Bitcoin', 'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400', 'current_price': 118493, 'market_cap': 2358267288670, 'market_cap_rank': 1, 'fully_diluted_valuation': 2358267288670, 'total_volume': 41773564159, 'high_24h': 119754, 'low_24h': 118335, 'price_change_24h': 157.89, 'price_change_percentage_24h': 0.13343, 'market_cap_change_24h': 5829225821, 'market_cap_change_percentage_24h': 0.2478, 'circulating_supply': 19898665.0, 'total_supply': 19898665.0, 'max_supply': 21000000.0, 'ath': 122838, 'ath_change_percentage': -3.59455, 'ath_date': '2025-07-14T07:56:01.937Z', 'atl': 67.81, 'atl_change_percentage': 174541.29541, 'atl_date': '2013-07-06T00:00:00.000Z', 'roi': None, 'last_updated': '2025-07-28T14:14:24.008Z'}, {'id': 'ethereum', 'symbol': 'eth', 'name': 'Ethereum', 'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628', 'current_price': 3844.63, 'market_cap': 464228229013, 'market_cap_rank': 2, 'fully_diluted_valuation': 464228229013, 'total_volume': 35416452744, 'high_24h': 3936.94, 'low_24h': 3802.27, 'price_change_24h': 30.93, 'price_change_percentage_24h': 0.81108, 'market_cap_change_24h': 3862149399, 'market_cap_change_percentage_24h': 0.83893, 'circulating_supply': 120710895.7118681, 'total_supply': 120710895.7118681, 'max_supply': None, 'ath': 4878.26, 'ath_change_percentage': -21.21529, 'ath_date': '2021-11-10T14:24:19.604Z', 'atl': 0.432979, 'atl_change_percentage': 887546.84175, 'atl_date': '2015-10-20T00:00:00.000Z', 'roi': {'times': 42.42919289151811, 'currency': 'btc', 'percentage': 4242.919289151811}, 'last_updated': '2025-07-28T14:14:18.942Z'}, {'id': 'ripple', 'symbol': 'xrp', 'name': 'XRP', 'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442', 'current_price': 3.19, 'market_cap': 189186639359, 'market_cap_rank': 3, 'fully_diluted_valuation': 319313125232, 'total_volume': 6374253737, 'high_24h': 3.32, 'low_24h': 3.17, 'price_change_24h': 0.00186671, 'price_change_percentage_24h': 0.0585, 'market_cap_change_24h': 141050149, 'market_cap_change_percentage_24h': 0.07461, 'circulating_supply': 59239646627.0, 'total_supply': 99985901574.0, 'max_supply': 100000000000.0, 'ath': 3.65, 'ath_change_percentage': -12.51656, 'ath_date': '2025-07-18T03:40:53.808Z', 'atl': 0.00268621, 'atl_change_percentage': 118653.95645, 'atl_date': '2014-05-22T00:00:00.000Z', 'roi': None, 'last_updated': '2025-07-28T14:14:23.588Z'}, {'id': 'tether', 'symbol': 'usdt', 'name': 'Tether', 'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661', 'current_price': 0.999937, 'market_cap': 163585284773, 'market_cap_rank': 4, 'fully_diluted_valuation': 163585284773, 'total_volume': 101397559885, 'high_24h': 1.0, 'low_24h': 0.999922, 'price_change_24h': -0.000393134624553704, 'price_change_percentage_24h': -0.0393, 'market_cap_change_24h': -40893167.15045166, 'market_cap_change_percentage_24h': -0.02499, 'circulating_supply': 163595317967.1743, 'total_supply': 163595317967.1743, 'max_supply': None, 'ath': 1.32, 'ath_change_percentage': -24.4229, 'ath_date': '2018-07-24T00:00:00.000Z', 'atl': 0.572521, 'atl_change_percentage': 74.65858, 'atl_date': '2015-03-02T00:00:00.000Z', 'roi': None, 'last_updated': '2025-07-28T14:14:22.257Z'}, {'id': 'binancecoin', 'symbol': 'bnb', 'name': 'BNB', 'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970', 'current_price': 843.76, 'market_cap': 117552287226, 'market_cap_rank': 5, 'fully_diluted_valuation': 117552287226, 'total_volume': 3649070766, 'high_24h': 858.34, 'low_24h': 795.07, 'price_change_24h': 48.69, 'price_change_percentage_24h': 6.12425, 'market_cap_change_24h': 6807756662, 'market_cap_change_percentage_24h': 6.14726, 'circulating_supply': 139288555.79, 'total_supply': 139288555.79, 'max_supply': 200000000.0, 'ath': 858.34, 'ath_change_percentage': -1.83337, ...

# %%
print(data[0])
# Out:
# {'id': 'bitcoin', 'symbol': 'btc', 'name': 'Bitcoin', 'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400', 'current_price': 118493, 'market_cap': 2358267288670, 'market_cap_rank': 1, 'fully_diluted_valuation': 2358267288670, 'total_volume': 41773564159, 'high_24h': 119754, 'low_24h': 118335, 'price_change_24h': 157.89, 'price_change_percentage_24h': 0.13343, 'market_cap_change_24h': 5829225821, 'market_cap_change_percentage_24h': 0.2478, 'circulating_supply': 19898665.0, 'total_supply': 19898665.0, 'max_supply': 21000000.0, 'ath': 122838, 'ath_change_percentage': -3.59455, 'ath_date': '2025-07-14T07:56:01.937Z', 'atl': 67.81, 'atl_change_percentage': 174541.29541, 'atl_date': '2013-07-06T00:00:00.000Z', 'roi': None, 'last_updated': '2025-07-28T14:14:24.008Z'}

# %% [markdown]
# **Преобразуем в DataFrame**

# %%
import pandas as pd

df = pd.DataFrame(data)
df[['id', 'symbol', 'current_price', 'market_cap', 'price_change_percentage_24h']]
# Out:
#              id symbol  current_price     market_cap  \
# 0       bitcoin    btc  118493.000000  2358267288670
# 1      ethereum    eth    3844.630000   464228229013
# 2        ripple    xrp       3.190000   189186639359
# 3        tether   usdt       0.999937   163585284773
# 4   binancecoin    bnb     843.760000   117552287226
# 5        solana    sol     190.290000   102418899282
# 6      usd-coin   usdc       0.999778    64163762194
# 7      dogecoin   doge       0.236791    35602416746
# 8  staked-ether  steth    3838.480000    34480156761
# 9          tron    trx       0.324230    30718302473
#
#    price_change_percentage_24h
# 0                      0.13343
# 1                      0.81108
# 2                      0.05850
# 3                     -0.03930
# 4                      6.12425
# 5                      2.27223
# 6                     -0.00947
# 7                     -0.33219
# 8                      0.69142
# 9                      0.76521

# %% [markdown]
# # Работа с API с авторизацией (CoinMarketCap)
#
# ## Регистрация и получение ключа
#
# * Зарегистрируйтесь на [CoinMarketCap](https://coinmarketcap.com/api/)
# * После регистрации получите `X-CMC_PRO_API_KEY`
#
# ## Пример документации:
#
# * Документация: [https://coinmarketcap.com/api/documentation/v1/](https://coinmarketcap.com/api/documentation/v1/)
# * Endpoint: `/v1/cryptocurrency/listings/latest`

# %% [markdown]
# ## Пример запроса с ключом

# %%
url = "https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest"
headers = {
    "Accepts": "application/json",
    "X-CMC_PRO_API_KEY": "YOUR_KEY"
}
params = {
    "start": "1",
    "limit": "10",
    "convert": "USD"
}

response = requests.get(url, headers=headers, params=params)
data = response.json()

# %% [markdown]
# ## Как понять структуру JSON?

# %%
import json
print(json.dumps(data, indent=2))
# Out:
# {
#   "status": {
#     "timestamp": "2025-07-28T14:21:46.092Z",
#     "error_code": 0,
#     "error_message": null,
#     "elapsed": 16,
#     "credit_count": 1,
#     "notice": null,
#     "total_count": 9442
#   },
#   "data": [
#     {
#       "id": 1,
#       "name": "Bitcoin",
#       "symbol": "BTC",
#       "slug": "bitcoin",
#       "num_market_pairs": 12268,
#       "date_added": "2010-07-13T00:00:00.000Z",
#       "tags": [
#         "mineable",
#         "pow",
#         "sha-256",
#         "store-of-value",
#         "state-channel",
#         "coinbase-ventures-portfolio",
#         "three-arrows-capital-portfolio",
#         "polychain-capital-portfolio",
#         "binance-labs-portfolio",
#         "blockchain-capital-portfolio",
#         "boostvc-portfolio",
#         "cms-holdings-portfolio",
#         "dcg-portfolio",
#         "dragonfly-capital-portfolio",
#         "electric-capital-portfolio",
#         "fabric-ventures-portfolio",
#         "framework-ventures-portfolio",
#         "galaxy-digital-portfolio",
#         "huobi-capital-portfolio",
#         "alameda-research-portfolio",
#         "a16z-portfolio",
#         "1confirmation-portfolio",
#         "winklevoss-capital-portfolio",
#         "usv-portfolio",
#         "placeholder-ventures-portfolio",
#         "pantera-capital-portfolio",
#         "multicoin-capital-portfolio",
#         "paradigm-portfolio",
#         "bitcoin-ecosystem",
#         "layer-1",
#         "ftx-bankruptcy-estate",
#         "2017-2018-alt-season",
#         "us-strategic-crypto-reserve",
#         "binance-ecosystem",
#         "binance-listing"
#       ],
#       "max_supply": 21000000,
#       "circulating_supply": 19898665,
#       "total_supply": 19898665,
#       "infinite_supply": false,
#       "platform": null,
#       "cmc_rank": 1,
#       "self_reported_circulating_supply": null,
#       "self_reported_market_cap": null,
#       "tvl_ratio": null,
#       "last_updated": "2025-07-28T14:20:00.000Z",
#       "quote": {
#         "USD": {
#           "price": 118270.62978497184,
#           "volume_24h": 61106571925.84776,
#           "volume_change_24h": 35.612,
#           "percent_change_1h": -0.31632439,
#           "percent_change_24h": -0.15865595,
#           "percent_change_7d": -0.64027925,
#           "percent_change_30d": 10.27494415,
#           "percent_change_60d": 10.42084727,
#           "percent_change_90d": 24.71995778,
#           "market_cap": 2353427641430.177,
#           "market_cap_dominance": 60.092,
#           "fully_diluted_market_cap": 2483683225484.41,
#           "tvl": null,
#           "last_updated": "2025-07-28T14:20:00.000Z"
#         }
#       }
#     },
#     {
#       "id": 1027,
#       "name": "Ethereum",
#       "symbol": "ETH",
#       "slug": "ethereum",
#       "num_market_pairs": 10414,
#       "date_added": "2015-08-07T00:00:00.000Z",
#       "tags": [
#         "pos",
#         "smart-contracts",
#         "ethereum-ecosystem",
#         "coinbase-ventures-portfolio",
#         "three-arrows-capital-portfolio",
#         "polychain-capital-portfolio",
#         "binance-labs-portfolio",
#         "blockchain-capital-portfolio",
#         "boostvc-portfolio",
#         "cms-holdings-portfolio",
#         "dcg-portfolio",
#         "dragonfly-capital-portfolio",
#         "electric-capital-portfolio",
#         "fabric-ventures-portfolio",
#         "framework-ventures-portfolio",
#         "hashkey-capital-portfolio",
#         "kenetic-capital-portfolio",
#         "huobi-capital-portfolio",
#         "alameda-research-portfolio",
#         "a16z-portfolio",
#         "1confirmation-portfolio",
#         "winklevoss-capital-portfolio",
#         "usv-portfolio",
#         "placeholder-ventures-portfolio",
#         "pantera-capital-portfolio",
#         "multicoin-capital-portfolio",
#         "paradigm-portfolio",
#         "ethereum-pow-ecosystem",
#         "layer-1",
#         "ftx-bankruptcy-estate",
#         "sora-ecosystem",
#         "rsk-rbtc-ecosystem",
#         "world-liberty-financial-portfolio",
#         "us-strategic-crypto-reserve",
#         "binance-ecosystem",
#         "binance-listing"
#       ],
#       "max_supply": null,
#       "circulating_supply": 120710895.7118682,
#       "total_supply": 120710895.7118682,
#       "infinite_supply": true,
#       "platform": null,
#       "cmc_rank": 2,
#       "self_reported_circulating_supply": null,
#       "self_reported_market_cap": null,
#       "tvl_ratio": null,
#       "last_updated": "2025-07-28T14:20:00.000Z",
#       "quote": {
#         "USD": {
#           "price": 3811.471055651508,
#           "volume_24h": 32215809174.541176,
#           "volume_change_24h": 35.8538,
#           "percent_change_1h": -1.14227798,
#           "percent_change_24h": -0.29098545,
#           "percent_change_7d": -0.84870036,
#           "percent_change_30d": 57.0070732,
#           "percent_change_60d": 45.12519029,
#           "percent_change_90d": 109.61240076,
#           "market_cap": 460086085107.55334,
#           "market_cap_dominance": 11.7478,
#           "fully_diluted_market_cap": 460086085107.55,
#           "tvl": null,
#           "last_updated": "2025-07-28T14:20:00.000Z"
#         }
#       }
#     },
#     {
#       "id": 52,
#       "name": "XRP",
#       "symbol": "XRP",
#       "slug": "xrp",
#       "num_market_pairs": 1661,
#       "date_added": "2013-08-04T00:00:00.000Z",
#       "tags": [
#         "medium-of-exchange",
#         "enterprise-solutions",
#         "xrp-ecosystem",
#         "arrington-xrp-capital-portfolio",
#         "galaxy-digital-portfolio",
#         "a16z-portfolio",
#         "pantera-capital-portfolio",
#         "ftx-bankruptcy-estate",
#         "2017-2018-alt-season",
#         "klaytn-ecosystem",
#         "made-in-america",
#         "us-strategic-crypto-reserve",
#         "binance-ecosystem",
#         "binance-listing"
#       ],
#       "max_supply": 100000000000,
#       "circulating_supply": 59239646627,
#       "total_supply": 99985901574,
#       "infinite_supply": false,
#       "platform": null,
#       "cmc_rank": 3,
#       "self_reported_circulating_supply": null,
#       "self_reported_market_cap": null,
#       "tvl_ratio": null,
#       "last_updated": "2025-07-28T14:19:00.000Z",
#       "quote": {
#         "USD": {
#           "price": 3.1737192385823056,
#           "volume_24h": 7303826313.269726,
#           "volume_change_24h": 80.3171,
#           "percent_change_1h": -1.06910393,
#           "percent_change_24h": -0.78975748,
#           "percent_change_7d": -12.09024593,
#           "percent_change_30d": 44.57864977,
#           "percent_change_60d": 39.4509279,
#           "percent_change_90d": 38.94608247,
#           "market_cap": 188010006186.92728,
#           "market_cap_dominance": 4.7999,
#           "fully_diluted_market_cap": 317371923858.23,
#           "tvl": null,
#           "last_updated": "2025-07-28T14:19:00.000Z"
#         }
#       }
#     },
#     {
#       "id": 825,
#       "name": "Tether USDt",
#       "symbol": "USDT",
#       "slug": "tether",
#       "num_market_pairs": 138781,
#       "date_added": "2015-02-25T00:00:00.000Z",
#       "tags": [
#         "stablecoin",
#         "asset-backed-stablecoin",
#         "usd-stablecoin",
#         "ethereum-pow-ecosystem",
#         "fiat-stablecoin",
#         "tron20-ecosystem",
#         "rsk-rbtc-ecosystem",
#         "world-liberty-financial-portfolio",
#         "binance-ecosystem",
#         "binance-listing",
#         "peaq-ecosystem",
#         "apertum-ecosystem"
#       ],
#       "max_supply": null,
#       "circulating_supply": 163595317967.17438,
#       "total_supply": 166810996205.40906,
#       "platform": {
#         "id": 1027,
#         "name": "Ethereum",
#         "symbol": "ETH",
#         "slug": "ethereum",
#         "token_address": "0xdac17f958d2ee523a2206206994597c13d831ec7"
#       },
#       "infinite_supply": true,
#       "cmc_rank": 4,
#       "self_reported_circulating_supply": null,
#       "self_reported_market_cap": null,
#       "tvl_ratio": null,
#       "last_updated": "2025-07-28T14:19:00.000Z",
#       "quote": {
#         "USD": {
#           "price": 1.0000474735877694,
#           "volume_24h": 115945844567.97855,
#           "volume_change_24h": 45.8376,
#           "percent_change_1h": 0.00349439,
#           "percent_change_24h": -0.04000171,
#           "percent_change_7d": -0.02619184,
#           "percent_change_30d": -0.02913572,
#           "percent_change_60d": -0.01993243,
#           "percent_change_90d": -0.03976954,
#           "market_cap": 163603084423.86053,
#           "market_cap_dominance": 4.1768,
#           "fully_diluted_market_cap": 166818915321.88,
#           "tvl": null,
#           "last_updated": "2025-07-28T14:19:00.000Z"
#         }
#       }
#     },
#     {
#       "id": 1839,
#       "name": "BNB",
#       "symbol": "BNB",
#       "slug": "bnb",
#       "num_market_pairs": 2640,
#       "date_added": "2017-07-25T00:00:00.000Z",
#       "tags": [
#         "marketplace",
#         "centralized-exchange",
#         "payments",
#         "smart-contracts",
#         "alameda-research-portfolio",
#         "multicoin-capital-portfolio",
#         "bnb-chain-ecosystem",
#         "layer-1",
#         "alleged-sec-securities",
#         "celsius-bankruptcy-estate",
#         "binance-ecosystem",
#         "binance-listing"
#       ],
#       "max_supply": null,
#       "circulating_supply": 139288554.78,
#       "total_supply": 139288554.78,
#       "infinite_supply": false,
#       "platform": null,
#       "cmc_rank": 5,
#       "self_reported_circulating_supply": null,
#       "self_reported_market_cap": null,
#       "tvl_ratio": null,
#       "last_updated": "2025-07-28T14:19:00.000Z",
#       "quote": {
#         "USD": {
#           "price": 840.5972685947614,
#           "volume_24h": 3941926120.227972,
#           "volume_change_24h": 102.3037,
#           "percent_change_1h": -0.90077054,
#           "percent_change_24h": 5.64928252,
#           "percent_change_7d": 8.12002641,
#           "percent_change_30d": 30.14616226,
#           "percent_change_60d": 23.35622237,
#           "percent_change_90d": 39.40862797,
#           "market_cap": 117085578694.5798,
#           "market_cap_dominance": 2.9892,
#           "fully_diluted_market_cap": 117085578694.58,
#           "tvl": null,
#           "last_updated": "2025-07-28T14:19:00.000Z"
#         }
#       }
#     },
#     {
#       "id": 5426,
#       "name": "Solana",
#       "symbol": "SOL",
#       "slug": "solana",
#       "num_market_pairs": 958,
#       "date_added": "2020-04-10T00:00:00.000Z",
#       "tags": [
#         "pos",
#         "platform",
#         "solana-ecosystem",
#         "cms-holdings-portfolio",
#         "kenetic-capital-portfolio",
#         "alameda-research-portfolio",
#         "multicoin-capital-portfolio",
#         "okx-ventures-portfolio",
#         "layer-1",
#         "ftx-bankruptcy-estate",
#         "alleged-sec-securities",
#         "cmc-crypto-awards-2024",
#         "made-in-america",
#         "us-strategic-crypto-reserve",
#         "binance-ecosystem",
#         "binance-listing"
#       ],
#       "max_supply": null,
#       "circulating_supply": 537922224.3430159,
#       "total_supply": 606183257.2423487,
#       "infinite_supply": true,
#       "platform": null,
#       "cmc_rank": 6,
#       "self_reported_circulating_supply": 525236893.3,
#       "self_reported_market_cap": 99183980422.36989,
#       "tvl_ratio": null,
#       "last_updated": "2025-07-28T14:19:00.000Z",
#       "quote": {
#         "USD": {
#           "price": 188.83665958651326,
#           "volume_24h": 6853501660.173723,
#           "volume_change_24h": 94.8685,
#           "percent_change_1h": -1.38539134,
#           "percent_change_24h": 1.32067946,
#           "percent_change_7d": -2.09276892,
#           "percent_change_30d": 28.84507454,
#           "percent_change_60d": 11.3201504,
#           "percent_change_90d": 27.98314179,
#           "market_cap": 101579435962.28212,
#           "market_cap_dominance": 2.5937,
#           "fully_diluted_market_cap": 114469621394.92,
#           "tvl": null,
#           "last_updated": "2025-07-28T14:19:00.000Z"
#         }
#       }
#     },
#     {
#       "id": 3408,
#       "name": "USDC",
#       "symbol": "USDC",
#       "slug": "usd-coin",
#       "num_market_pairs": 29902,
#       "date_added": "2018-10-08T00:00:00.000Z",
#       "tags": [
#         "medium-of-exchange",
#         "stablecoin",
#         "asset-backed-stablecoin",
#         "coinbase-ventures-portfolio",
#         "usd-stablecoin",
#         "ethereum-pow-ecosystem",
#         "fiat-stablecoin",
#         "tron20-ecosystem",
#         "made-in-america",
#         "world-liberty-financial-portfolio",
#         "binance-ecosystem",
#         "binance-listing"
#       ],
#       "max_supply": null,
#       "circulating_supply": 64176539622.43386,
#       "total_supply": 64176539622.43386,
#       "platform": {
#         "id": 1027,
#         "name": "Ethereum",
#         "symbol": "ETH",
#         "slug": "ethereum",
#         "token_address": "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"
#       },
#       "infinite_supply": false,
#       "cmc_rank": 7,
#       "self_reported_circulating_supply": 60901219650.23,
#       "self_reported_market_cap": 60891062069.370346,
#       "tvl_ratio": null,
#       "last_updated": "2025-07-28T14:19:00.000Z",
#       "quote": {
#         "USD": {
#           "price": 0.9998332121931548,
#           "volume_24h": 12935025492.201506,
#           "volume_change_24h": 53.577,
#           "percent_change_1h": 0.00168561,
#           "percent_change_24h": -0.02083067,
#           "percent_change_7d": -0.009324,
#           "percent_change_30d": -0.00637519,
#           "percent_change_60d": 0.00196818,
#           "percent_change_90d": -0.02072302,
#           "market_cap": 64165835758.13932,
#           "market_cap_dominance": 1.6384,
#           "fully_diluted_market_cap": 64165835758.14,
#           "tvl": null,
#           "last_updated": "2025-07-28T14:19:00.000Z"
#         }
#       }
#     },
#     {
#       "id": 74,
#       "name": "Dogecoin",
#       "symbol": "DOGE",
#       "slug": "dogecoin",
#       "num_market_pairs": 1262,
#       "date_added": "2013-12-15T00:00:00.000Z",
#       "tags": [
#         "mineable",
#         "pow",
#         "scrypt",
#         "medium-of-exchange",
#         "memes",
#         "payments",
#         "doggone-doggerel",
#         "osmosis-ecosystem",
#         "ftx-bankruptcy-estate",
#         "animal-memes",
#         "made-in-america",
#         "binance-ecosystem",
#         "binance-listing"
#       ],
#       "max_supply": null,
#       "circulating_supply": 150283536383.70526,
#       "total_supply": 150283536383.70526,
#       "infinite_supply": true,
#       "platform": null,
#       "cmc_rank": 8,
#       "self_reported_circulating_supply": null,
#       "self_reported_market_cap": null,
#       "tvl_ratio": null,
#       "last_updated": "2025-07-28T14:20:00.000Z",
#       "quote": {
#         "USD": {
#           "price": 0.2349414112147072,
#           "volume_24h": 2677401517.486699,
#           "volume_change_24h": 67.9073,
#           "percent_change_1h": -1.6972826,
#           "percent_change_24h": -1.48656455,
#           "percent_change_7d": -15.60428933,
#           "percent_change_30d": 45.00815531,
#           "percent_change_60d": 7.11112759,
#           "percent_change_90d": 31.64934338,
#           "market_cap": 35307826120.32451,
#           "market_cap_dominance": 0.9015,
#           "fully_diluted_market_cap": 35307826120.32,
#           "tvl": null,
#           "last_updated": "2025-07-28T14:20:00.000Z"
#         }
#       }
#     },
#     {
#       "id": 1958,
#       "name": "TRON",
#       "symbol": "TRX",
#       "slug": "tron",
#       "num_market_pairs": 1206,
#       "date_added": "2017-09-13T00:00:00.000Z",
#       "tags": [
#         "media",
#         "payments",
#         "tron-ecosystem",
#         "layer-1",
#         "dwf-labs-portfolio",
#         "alleged-sec-securities",
#         "2017-2018-alt-season",
#         "tron20-ecosystem",
#         "world-liberty-financial-portfolio",
#         "binance-ecosystem",
#         "binance-listing"
#       ],
#       "max_supply": null,
#       "circulating_supply": 94726820663.54,
#       "total_supply": 94726845531.33086,
#       "infinite_supply": true,
#       "platform": null,
#       "cmc_rank": 9,
#       "self_reported_circulating_supply": 71659659264,
#       "self_reported_market_cap": 23203472903.57737,
#       "tvl_ratio": null,
#       "last_updated": "2025-07-28T14:20:00.000Z",
#       "quote": {
#         "USD": {
#           "price": 0.32380104987792213,
#           "volume_24h": 1012563278.2661952,
#           "volume_change_24h": 77.8641,
#           "percent_change_1h": -0.84490722,
#           "percent_change_24h": 0.58267839,
#           "percent_change_7d": 2.61766691,
#           "percent_change_30d": 17.4488757,
#           "percent_change_60d": 17.39768798,
#           "percent_change_90d": 31.51613582,
#           "market_cap": 30672643982.451897,
#           "market_cap_dominance": 0.7832,
#           "fully_diluted_market_cap": 30672652034.67,
#           "tvl": null,
#           "last_updated": "2025-07-28T14:20:00.000Z"
#         }
#       }
#     },
#     {
#       "id": 2010,
#       "name": "Cardano",
#       "symbol": "ADA",
#       "slug": "cardano",
#       "num_market_pairs": 1554,
#       "date_added": "2017-10-01T00:00:00.000Z",
#       "tags": [
#         "dpos",
#         "pos",
#         "platform",
#         "research",
#         "smart-contracts",
#         "staking",
#         "cardano-ecosystem",
#         "cardano",
#         "layer-1",
#         "alleged-sec-securities",
#         "2017-2018-alt-season",
#         "made-in-america",
#         "us-strategic-crypto-reserve",
#         "binance-ecosystem",
#         "binance-listing"
#       ],
#       "max_supply": 45000000000,
#       "circulating_supply": 35408492715.29012,
#       "total_supply": 44990977542.77037,
#       "infinite_supply": false,
#       "platform": null,
#       "cmc_rank": 10,
#       "self_reported_circulating_supply": null,
#       "self_reported_market_cap": null,
#       "tvl_ratio": null,
#       "last_updated": "2025-07-28T14:20:00.000Z",
#       "quote": {
#         "USD": {
#           "price": 0.8115786460515809,
#           "volume_24h": 1202799157.101858,
#           "volume_change_24h": 25.7676,
#           "percent_change_1h": -1.50856168,
#           "percent_change_24h": -1.37917221,
#           "percent_change_7d": -12.30963063,
#           "percent_change_30d": 45.36698067,
#           "percent_change_60d": 9.99633204,
#           "percent_change_90d": 13.95812264,
#           "market_cap": 28736776576.602425,
#           "market_cap_dominance": 0.7338,
#           "fully_diluted_market_cap": 36521039072.32,
#           "tvl": null,
#           "last_updated": "2025-07-28T14:20:00.000Z"
#         }
#       }
#     }
#   ]
# }

# %% [markdown]
# ## Извлекаем полезное в DataFrame

# %%
coins = data['data']  # список словарей

df = pd.DataFrame([{
    "name": coin["name"],
    "symbol": coin["symbol"],
    "price": coin["quote"]["USD"]["price"],
    "market_cap": coin["quote"]["USD"]["market_cap"],
    "change_24h": coin["quote"]["USD"]["percent_change_24h"]
} for coin in coins])

df
# Out:
#           name symbol          price    market_cap  change_24h
# 0      Bitcoin    BTC  118270.629785  2.353428e+12   -0.158656
# 1     Ethereum    ETH    3811.471056  4.600861e+11   -0.290985
# 2          XRP    XRP       3.173719  1.880100e+11   -0.789757
# 3  Tether USDt   USDT       1.000047  1.636031e+11   -0.040002
# 4          BNB    BNB     840.597269  1.170856e+11    5.649283
# 5       Solana    SOL     188.836660  1.015794e+11    1.320679
# 6         USDC   USDC       0.999833  6.416584e+10   -0.020831
# 7     Dogecoin   DOGE       0.234941  3.530783e+10   -1.486565
# 8         TRON    TRX       0.323801  3.067264e+10    0.582678
# 9      Cardano    ADA       0.811579  2.873678e+10   -1.379172

# %% [markdown]
# ## Как понимать документацию:
#
# * `GET` — означает, что нужно делать GET-запрос
# * В скобках `required` / `optional` — обязательный или необязательный параметр
# * Тип данных: `string`, `int`, `float`
#
# ## Как дебажить:
#
# * `response.status_code != 200` — значит, ошибка
# * `response.text` — покажет текст ошибки
# * `try-except` — ловить ошибки

# %% [markdown]
# ## Получить топ-10 криптовалют по рыночной капитализации

# %%
import plotly.express as px

def get_crypto_data(limit=10):
    url = "https://api.coingecko.com/api/v3/coins/markets"
    params = {
        "vs_currency": "usd",
        "order": "market_cap_desc",
        "per_page": limit,
        "page": 1,
        "sparkline": False
    }

    response = requests.get(url, params=params)
    data = response.json()

    df = pd.DataFrame(data)
    df = df[[
        'id', 'symbol', 'name', 'current_price',
        'market_cap', 'price_change_percentage_24h'
    ]]
    return df
df = get_crypto_data(limit=10)

# %%
df
# Out:
#              id symbol               name  current_price     market_cap  \
# 0       bitcoin    btc            Bitcoin  118186.000000  2354509382851
# 1      ethereum    eth           Ethereum    3809.210000   461851670439
# 2        ripple    xrp                XRP       3.170000   188334493323
# 3        tether   usdt             Tether       0.999976   163587776776
# 4   binancecoin    bnb                BNB     839.670000   117067197110
# 5        solana    sol             Solana     188.970000   101753816804
# 6      usd-coin   usdc               USDC       0.999819    64163036101
# 7      dogecoin   doge           Dogecoin       0.233902    35374503413
# 8  staked-ether  steth  Lido Staked Ether    3801.820000    34219415481
# 9          tron    trx               TRON       0.323792    30680403404
#
#    price_change_percentage_24h
# 0                     -0.19794
# 1                     -0.19779
# 2                     -0.85763
# 3                     -0.03425
# 4                      5.43210
# 5                      1.48258
# 6                     -0.00833
# 7                     -1.50225
# 8                     -0.36585
# 9                      0.62395

# %% [markdown]
# ## Отфильтровать монеты с падением более чем на 1%

# %%
falling = df[df['price_change_percentage_24h'] < -1]
falling
# Out:
#          id symbol      name  current_price   market_cap  \
# 7  dogecoin   doge  Dogecoin       0.233902  35374503413
#
#    price_change_percentage_24h
# 7                     -1.50225

# %% [markdown]
# ## Построить barplot

# %%
fig = px.bar(
    df,
    x='name',
    y='market_cap',
    title='Топ-10 криптовалют по рыночной капитализации',
    text='market_cap',
    labels={'name': 'Криптовалюта', 'market_cap': 'Рыночная капитализация ($)'}
)
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.update_layout(yaxis_tickformat="$,.0f")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8bb0e2cf-e520-4855-947f-af84c2877e51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8bb0e2cf-e520-4855-947f-af84c2877e51")) {                    Plotly.newPlot(                        "8bb0e2cf-e520-4855-947f-af84c2877e51",                        [{"alignmentgroup":"True","hovertemplate":"Криптовалюта=%{x}\u003cbr\u003eРыночная капитализация ($)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[2354509382851.0,461851670439.0,188334493323.0,163587776776.0,117067197110.0,101753816804.0,64163036101.0,35374503413.0,34219415481.0,30680403404.0],"textposition":"outside","x":["Bitcoin","Ethereum","XRP","Tether","BNB","Solana","USDC","Dogecoin","Lido Staked Ether","TRON"],"xaxis":"x","y":[2354509382851,461851670439,188334493323,163587776776,117067197110,101753816804,64163036101,35374503413,34219415481,30680403404],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewid ...

# %%
fig = px.bar(
    falling,
    x='name',
    y='price_change_percentage_24h',
    title='Криптовалюты с падением > 1% за 24 часа',
    text='price_change_percentage_24h',
    labels={'name': 'Криптовалюта', 'price_change_percentage_24h': 'Изменение цены (%)'}
)
fig.update_traces(texttemplate='%{text:.2f}%', textposition='outside')
fig.update_layout(yaxis_tickformat=".2f")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="496b7882-85e9-46ed-bb83-d8620945ed1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("496b7882-85e9-46ed-bb83-d8620945ed1c")) {                    Plotly.newPlot(                        "496b7882-85e9-46ed-bb83-d8620945ed1c",                        [{"alignmentgroup":"True","hovertemplate":"Криптовалюта=%{x}\u003cbr\u003eИзменение цены (%)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[-1.50225],"textposition":"outside","x":["Dogecoin"],"xaxis":"x","y":[-1.50225],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}%"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","mar ...
