# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/da_2603/blob/main/lesson_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

d = {'a': 1, 'b': 2, 'c': 3}
ser = pd.Series(data=d)
ser
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ser = pd.Series(data=[123, 343, 213, 234, 1322])
ser
# Out:
# 0     123
# 1     343
# 2     213
# 3     234
# 4    1322
# dtype: int64

# %%
d = {'col1': [1, 2], 'col2': [3, 4]}

df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %%
d = {'col1': [1, 2], 'col2': [3, 4]}

df = pd.Series(data=d)
df
# Out:
# col1    [1, 2]
# col2    [3, 4]
# dtype: object

# %%
from google.colab import files
uploaded = files.upload()

# %%
df = pd.read_csv('titanic.csv')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv', delimiter=',', encoding='utf-8')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Sex'].value_counts()
#     for x_label, grp in _df_48.groupby('Name')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Name')
# _ = plt.ylabel('Sex')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Ticket'].value_counts()
#     for x_label, grp in _df_49.groupby('Sex')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Sex')
# _ = plt.ylabel('Ticket')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['Cabin'].value_counts()
#     for x_label, grp in _df_50.groupby('Ticket')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('Ticket')
# _ = plt.ylabel('Cabin')
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
names = df['Name']
# to lowercase
names = names.str.lower()
names
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_new = df[['Name', 'Sex', 'Age']]
df_new
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %%
df.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df.rename(columns={'Name': 'name', 'Sex': 'sex', 'Age': 'age'}, inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['is_adult'] = df['age'] >= 18

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(columns=['is_adult'], inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   name     sex   age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['age'] = df['age'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-36-9b0df8191b9d> in <cell line: 0>()
# ----> 1 df['age'] = df['age'].astype(int)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   name         891 non-null    object
#  4   sex          891 non-null    object
#  5   age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
x = df.iloc[20]
type(x)
# Out:
# pandas.core.series.Series

# %%
df.loc[20]
# Out:
# PassengerId                      21
# Survived                          0
# Pclass                            2
# name           Fynney, Mr. Joseph J
# sex                            male
# age                            35.0
# SibSp                             0
# Parch                             0
# Ticket                       239865
# Fare                           26.0
# Cabin                           NaN
# Embarked                          S
# Name: 20, dtype: object

# %%
df[::50]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 50            51         0       3
# 100          101         0       3
# 150          151         0       2
# 200          201         0       3
# 250          251         0       3
# 300          301         1       3
# 350          351         0       3
# 400          401         1       3
# 450          451         0       2
# 500          501         0       3
# 550          551         1       1
# 600          601         1       2
# 650          651         0       3
# 700          701         1       1
# 750          751         1       2
# 800          801         0       2
# 850          851         0       3
#
#                                                   name     sex   age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 50                          Panula, Master. Juha Niilo    male   7.0      4
# ...

# %%
df.sort_values(by='age', inplace=True, ascending=False)
df
# Out:
#      PassengerId  Survived  Pclass                                      name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 96            97         0       1                 Goldschmidt, Mr. George B
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values(by=['age', 'sex'], inplace=True, ascending=[False, True])
df
# Out:
#      PassengerId  Survived  Pclass                                  name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
# ..           ...       ...     ...                                   ...
# 839          840         1       1                  Marechal, Mr. Pierre
# 846          847         0       3              Sage, Mr. Douglas Bullen
# 859          860         0       3                      Razi, Mr. Raihed
# 868          869         0       3           van Melkebeke, Mr. Philemon
# 878          879         0       3                    Laleff, Mr. Kristo
#
#       sex   age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %%
df_male = df[df['sex'] == 'male']
df_female = df[df['sex'] == 'female']

# %%
df_male
# Out:
#      PassengerId  Survived  Pclass                                  name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
# ..           ...       ...     ...                                   ...
# 839          840         1       1                  Marechal, Mr. Pierre
# 846          847         0       3              Sage, Mr. Douglas Bullen
# 859          860         0       3                      Razi, Mr. Raihed
# 868          869         0       3           van Melkebeke, Mr. Philemon
# 878          879         0       3                    Laleff, Mr. Kristo
#
#       sex   age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %%
df_female
# Out:
#      PassengerId  Survived  Pclass  \
# 483          484         1       3
# 275          276         1       1
# 829          830         1       1
# 366          367         1       1
# 268          269         1       1
# ..           ...       ...     ...
# 727          728         1       3
# 792          793         0       3
# 849          850         1       1
# 863          864         0       3
# 888          889         0       3
#
#                                                  name     sex   age  SibSp  \
# 483                            Turkula, Mrs. (Hedwig)  female  63.0      0
# 275                 Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 829         Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 268     Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df_old_man = df[(df['age'] > 60) & (df['sex'] == 'male')] # & - and, | - or, ~ - not

# %%
df_old_man
# Out:
#      PassengerId  Survived  Pclass                                  name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 33            34         0       2                 Wheadon, Mr. Edward H
# 280          281         0       3                      Duane, Mr. Frank
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 456          457         0       1             Millet, Mr. Francis Davis
# 545          546         0       1          Nicholson, Mr. Arthur Ernest
# ...

# %%
df_f1 = df[df['Embarked'].isin(['S', 'C'])]
df_f1
# Out:
#      PassengerId  Survived  Pclass                                  name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 745          746         0       1          Crosby, Capt. Edward Gifford
# ..           ...       ...     ...                                   ...
# 839          840         1       1                  Marechal, Mr. Pierre
# 846          847         0       3              Sage, Mr. Douglas Bullen
# 859          860         0       3                      Razi, Mr. Raihed
# 868          869         0       3           van Melkebeke, Mr. Philemon
# 878          879         0       3                    Laleff, Mr. Kristo
#
#       sex   age  SibSp  Parch     Ticket     Fare Cabin Embarked
# ...

# %%
df_mrs = df[df['name'].str.contains('Mrs')]
df_mrs
# Out:
#      PassengerId  Survived  Pclass  \
# 483          484         1       3
# 829          830         1       1
# 366          367         1       1
# 268          269         1       1
# 772          773         0       2
# ..           ...       ...     ...
# 457          458         1       1
# 533          534         1       3
# 578          579         0       3
# 669          670         1       1
# 849          850         1       1
#
#                                                   name     sex   age  SibSp  \
# 483                             Turkula, Mrs. (Hedwig)  female  63.0      0
# 829          Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
# 366   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 268      Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 772                                  Mack, Mrs. (Mary)  female  57.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
res = df[(df['sex'] == 'male') & (df['Survived'] == 1)]
res['age'].mean()
# Out:
# np.float64(27.276021505376345)

# %%
res = df[(df['sex'] == 'female') & (df['Survived'] == 1)]
res['age'].mean()
# Out:
# np.float64(28.84771573604061)

# %%
res = df[(df['sex'] == 'male') & (df['Survived'] == 1)]
res['age'].max()
# Out:
# 80.0

# %%
res = df[(df['sex'] == 'female') & (df['Survived'] == 1)]
res['age'].max()
# Out:
# 63.0
